# %%
import pandas as pd
for f in ['branches','customers','loans','repayments']:
    df = pd.read_csv(f'{f}.csv')
    print(f"\n{f}: {df.shape}")
    print(df.columns.tolist())
    print(df.head(2))
# Out:
# branches: (40, 5)
# ['branch_id', 'branch_name', 'city', 'state', 'region']
#   branch_id              branch_name     city          state region
# 0     BR001    FinServe Delhi Branch    Delhi          Delhi  North
# 1     BR002  FinServe Lucknow Branch  Lucknow  Uttar Pradesh  North
#
# customers: (8000, 10)
# ['customer_id', 'first_name', 'last_name', 'age', 'gender', 'city', 'state', 'credit_score', 'employment_type', 'monthly_income']
#   customer_id first_name last_name  age  gender    city          state  \
# 0   CUST00001      Divya     Joshi   43  Female  Ranchi      Jharkhand
# 1   CUST00002      Divya     Verma   23  Female  Meerut  Uttar Pradesh
#
#    credit_score employment_type  monthly_income
# 0         600.0   Self-employed        16152.32
# 1         403.0   Self-Employed        22991.02
#
# loans: (10150, 9)
# ['loan_id', 'customer_id', 'branch_id', 'loan_type', 'loan_amount', 'tenure_months', 'interest_rate', 'disbursement_date', 'loan_status']
# ...
